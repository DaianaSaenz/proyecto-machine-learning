# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

df = pd.read_csv("../data/processed/clientes_banco.csv")

# Transformo a numericos los valores de las variables categoricas para que el modelo pueda procesarlos
variables_categoricas = ["genero", "nivel_educativo", "estado_civil", "banda_salarial", "categoria_tarjeta"]
codificacion = OneHotEncoder()
codificacion.fit(df[variables_categoricas])
lista_cod_columnas = codificacion.get_feature_names(variables_categoricas)
df_cod_variables = pd.DataFrame(codificacion.transform(df[variables_categoricas]).toarray(), columns=lista_cod_columnas)
df_total_variables = pd.concat([df, df_cod_variables], axis=1).drop(columns=variables_categoricas)
df_total_variables.info()
df_total_variables.head()

print(list(df_total_variables))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10027 entries, 0 to 10026
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   permanencia                        10027 non-null  object
#  1   edad                               10027 non-null  int64
#  2   num_personas_dependientes          10027 non-null  int64
#  3   num_meses_cliente                  10027 non-null  int64
#  4   productos_financieros_contratados  10027 non-null  int64
#  5   num_meses_inactivo_12_meses        10027 non-null  int64
#  6   veces_contactado_12_meses          10027 non-null  int64
#  7   limite_credito                     10027 non-null  float64
#  8   saldo_pendiente_tarjeta            10027 non-null  int64
#  9   credito_disponible                 10027 non-null  float64
#  10  dif_cantidad_gastada_trimestre     10027 non-null  float64
# ...

# %%
# Separar en conjuntos de entrenamiento y prueba
x = df_total_variables.drop(columns=["permanencia"])
y = df_total_variables["permanencia"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=50)

# Entrenar el modelo de regresión logística
modelo_regresion = LogisticRegression()
modelo_regresion.fit(x_train, y_train)

# Evaluar el modelo en el conjunto de prueba
y_prediccion = modelo_regresion.predict(x_test)
print(classification_report(y_test, y_prediccion))
print('Precisión: {:.3f}'.format(accuracy_score(y_test,y_prediccion)))
# Out:
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.75      0.53      0.62       336
# Existing Customer       0.91      0.96      0.94      1670
#
#          accuracy                           0.89      2006
#         macro avg       0.83      0.75      0.78      2006
#      weighted avg       0.88      0.89      0.88      2006
#
# Precisión: 0.891
# c:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#PREDICCION REAL
df_datos_para_predecir = pd.read_csv("../data/processed/clientes_banco.csv")

x = df_datos_para_predecir.drop("permanencia", axis=1)
y = df_datos_para_predecir["permanencia"]

# codificar variables categóricas
variables_categoricas = ["genero", "nivel_educativo", "estado_civil", "banda_salarial", "categoria_tarjeta"]
codificacion = OneHotEncoder(handle_unknown='ignore')
x_codificadas = pd.DataFrame(codificacion.fit_transform(x[variables_categoricas]).toarray(), columns=codificacion.get_feature_names(variables_categoricas))
x = x.drop(variables_categoricas, axis=1)
x = pd.concat([x, x_codificadas], axis=1)

nueva_prediccion = modelo_regresion.predict(x)

#permite ver mas resultados en el print
np.set_printoptions(threshold=np.inf)


print(nueva_prediccion)
# Out:
# ['Existing Customer' 'Existing Customer' 'Existing Customer' ...
#  'Attrited Customer' 'Existing Customer' 'Existing Customer']
# ['Existing Customer' 'Existing Customer' 'Existing Customer'
#  'Attrited Customer' 'Existing Customer' 'Attrited Customer'
#  'Existing Customer' 'Existing Customer' 'Existing Customer'
#  'Existing Customer' 'Existing Customer' 'Attrited Customer'
#  'Existing Customer' 'Attrited Customer' 'Existing Customer'
#  'Existing Customer' 'Existing Customer' 'Attrited Customer'
#  'Attrited Customer' 'Existing Customer' 'Attrited Customer'
#  'Existing Customer' 'Existing Customer' 'Existing Customer'
#  'Existing Customer' 'Attrited Customer' 'Existing Customer'
#  'Existing Customer' 'Existing Customer' 'Existing Customer'
#  'Existing Customer' 'Existing Customer' 'Attrited Customer'
#  'Existing Customer' 'Attrited Customer' 'Existing Customer'
#  'Existing Customer' 'Existing Customer' 'Existing Customer'
# ...
